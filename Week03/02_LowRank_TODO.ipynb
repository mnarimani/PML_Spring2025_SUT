# %% [markdown]
# ## 🧮 Python Lab: Matrix Decomposition
# #### Matrix (Low-Rank) Approximation: Image Compression
# > [Principles of ML course](https://github.com/mnarimani/PML_Spring2025_SUT) - Spring 2025 - Sharif <br>
# > Lab sessions - Session 3 - March 1, 2025 <br>
# > Author: M Narimani <br>

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/mnarimani/PML_Spring2025_SUT/blob/main/Week03/02_LowRank_TODO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/mnarimani/PML_Spring2025_SUT/blob/main/Week03/02_LowRank_TODO.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ## 🛠️ Setup: Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import requests
from PIL import Image
from io import BytesIO

# %% [markdown]
# ## 1️⃣ Practical Application: Image Compression
# Apply SVD to real image data

# %%
# Download image from web
url = "https://raw.githubusercontent.com/scikit-image/scikit-image/main/skimage/data/astronaut.png"
response = requests.get(url)
image = Image.open(BytesIO(response.content))
image = np.array(image)
image = image.mean(axis=2) # Convert to grayscale

plt.figure(figsize=(4, 3))
plt.imshow(image, cmap='gray')
plt.show()

# %% [markdown]
# ## 2️⃣ Performing Singular Value Decomposition

# %% [markdown]
# > **TODO**: Perform SVD on image matrix

# %%
# U_img, s_img, VT_img = ?

# %% [markdown]
# ## 3️⃣ Low-Rank Approximation

# %% [markdown]
# > **TODO**: Create compressed approximation

# %%
k = 50 # Number of components to retain

# compressed = ?

plt.figure(figsize=(7, 3))
plt.subplot(121), plt.imshow(image, cmap='gray'), plt.title(f'Original (Rank {np.linalg.matrix_rank(image)})')
plt.subplot(122), plt.imshow(compressed, cmap='gray'), plt.title(f'Compressed (k={k})')
plt.show()

# %% [markdown]
# ## 4️⃣ Practical Task: Error Analysis
# Compute reconstruction error vs number of components

# %% [markdown]
# > **TODO**: Calculate Frobenius norm error

# %%
# def reconstruction_error(k):
#     ...
# errors = [reconstruction_error(i) for i in range(1, 201)]

plt.figure(figsize=(7, 3))
plt.plot(np.arange(1,201), errors)
plt.xlabel('Number of Components'), plt.ylabel('Reconstruction Error')
plt.title('Error vs Compression Level')
plt.show()
